# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pytesseract
# !sudo apt install tesseract-ocr
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 16 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (4,336 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !pip install wand
# !apt-get install libmagickwand-dev
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.6/143.6 kB 1.6 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-rsvg-2.0 gsfonts
#   imagemagick-6-common libblkid-dev libcairo-script-interpreter2 libcairo2-dev
#   libdjvulibre-dev libdjvulibre-text libdjvulibre21 libffi-dev
#   libfftw3-double3 libgdk-pixbuf-2.0-dev libgdk-pixbuf2.0-bin libglib2.0-dev
#   libglib2.0-dev-bin libgs9 libgs9-common libice-dev libidn12 libijs-0.35
#   libjbig2dec0 libjxr-tools libjxr0 liblcms2-dev liblqr-1-0 liblqr-1-0-dev
#   liblzo2-2 libmagickcore-6-arch-config libmagickcore-6-headers
#   libmagickcore-6.q16-6 libmagickcore-6.q16-6-extra libmagickcore-6.q16-dev
#   libmagickwand-6-headers libmagickwand-6.q16-6 libmagickwand-6.q16-dev
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


image_path = '/content/Nirmala Precision Tools-1.jpg'
image = mpimg.imread(image_path)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
import spacy
import pickle
import random
import os
import cv2 as cv
import pytesseract
from wand.image import Image
from PIL import Image as Img

# Import required modules

# %%
import os
import pytesseract
from PIL import Image

# Path to the directory containing your images
image_dir = '/content/drive/MyDrive/hhh'

# List to store the extracted text from each image
extracted_text_list = []

# Iterate through each image in the directory
for i, filename in enumerate(os.listdir(image_dir)):
    if filename.endswith('.jpg'):
        image_path = os.path.join(image_dir, filename)

        # Use Tesseract OCR to extract text from the image
        extracted_text = pytesseract.image_to_string(Image.open(image_path))

        # Append the extracted text to the list
        extracted_text_list.append(extracted_text)

        # Print the extracted text from the current image
        print(f"Extracted Text from Image {i + 1}:\n{extracted_text}\n{'-' * 40}")

# Now you have the extracted text from each image in the extracted_text_list
# Out:
# Extracted Text from Image 1:
# GSTIN:
# 27AAACU9498B1Z0 w.e.f 01/07/2017
#
# Serial No. of Invoice: U-1/19-20/947
# Date of Invoice : 13-08-2019
#
# Details of Receiver (Billed to)
#
# (UNDER RULES 7 - SECTION 31)
# STATE : MAHARASHTRA / STATE CODE : MH - 27 |__| Quadruplicate For Ack. / Extra
#
# URJAYANT ENGINEERING PVT LTD
# F-6, MIDC AMBAD, NASHIK (MH) - 422010.
# CONTACT NO : (0253) - 6622430/6622444/6622445
# E Mail ID : pawan.urjayant@sangaigroup.com / Web : www.sangaigroup.com
# CIN NO: U74200MH2007PTC176973
#
#
#
# TAX INVOICE CUM CHALLAN [.— [original For Recipient
#
#
#
# Duplicate For Transporter
# Triplicate For Supplier
#
#
#
#
#
#
#
#
#
#
#
# URJAYANT
#
# Performance Inspires ‘Trust !
# A
#
#
#
#
#
#
#
# CN1906041
# Purchase Order No.: /CN1906572 Mode of Transport :
#
#
#
# By Road
# MH15B)1773
#
#
#
#
#
# P.O Date: 09-05-2019 /09-07-2019 |Vehicle No:
#
#
#
#
# Vendor Code : P00033703 Date & Time of Supply 13-08-2019 15.22 PM
# Payment Terms : 90 Days $ NASHIK
# ...

# %%
import os
import pytesseract
from PIL import Image

# Path to the directory containing your images
image_dir = '/content/drive/MyDrive/hhh'

# List to store the extracted text from each image
extracted_text_list = []

# Iterate through each image in the directory
for i, filename in enumerate(os.listdir(image_dir)):
    if filename.endswith('.jpg'):
        image_path = os.path.join(image_dir, filename)

        # Use Tesseract OCR to extract text from the image
        extracted_text = pytesseract.image_to_string(Image.open(image_path))

        # Append the extracted text to the list
        extracted_text_list.append(extracted_text)

        # Print the extracted text from the second image
        if i == 2:
            print(f"Extracted Text from Image {i + 1}:\n{extracted_text}\n{'-' * 40}")
            break  # Exit the loop after printing text from the second image

# Now you have the extracted text from each image in the extracted_text_list
# Out:
# Extracted Text from Image 3:
#
#
# An ISO 9001:2015 Certified Company
#
# Survey No. 527, Nashik-Mumbai Highway, Village Gonde (Dumala), Tal. Igatpuri, Dist. Nashik, Pin 422403, Maharashtra, India.
# Phone : +91 9552 193193 | Email : sunil.ghube@shakuntechpack.com / shakuntechpac@yahoo.com | Web : www.shakuntechpack.com
#
# CIN:U74950MH2010PTC208397 | PAN No.: AAOCS8097E | IEC No.: 3110018179 | GSTIN: 27AAOCS8097E1ZP
#
# Original for Receipient/Buyer
#
# TAX INVOICE
# PO No.: CG1902164 PO Dt. 08-Aug-2019] Invoice No. 19-20 / 0630 Invoice Date: 13-Aug-2019
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Details of Consignee (Shipped to) :
# PANCHASHIL INDUSTRIES (NASHIK) PVT. LTD.
#
# Details of Receiver (Billed to) :
# EFACEC INDIA PVT.LTD. (C-4)
#
#
#
#
#
#
#
#
#
#
#
#
#
# PLOT NO C-4 PLOT NO D-50
# GARWARE - XLO LINK ROAD MIDC AREA
#
# MIDC AREA AMBAD SATPUR
#
# NASHIK Pin: 422010 NASHIK Pin:
#
# Maharashtra State Code - MH-27 Maharashtra State Code - MH-27
#
#
#
#
#
#
#
#
#
# ...

# %%
import re

# Example extracted text
text = """
Extracted Text from Image 3:


An ISO 9001:2015 Certified Company

Survey No. 527, Nashik-Mumbai Highway, Village Gonde (Dumala), Tal. Igatpuri, Dist. Nashik, Pin 422403, Maharashtra, India.
Phone : +91 9552 193193 | Email : sunil.ghube@shakuntechpack.com / shakuntechpac@yahoo.com | Web : www.shakuntechpack.com

CIN:U74950MH2010PTC208397 | PAN No.: AAOCS8097E | IEC No.: 3110018179 | GSTIN: 27AAOCS8097E1ZP

Original for Receipient/Buyer

TAX INVOICE
PO No.: CG1902164 PO Dt. 08-Aug-2019] Invoice No. 19-20 / 0630 Invoice Date: 13-Aug-2019














Details of Consignee (Shipped to) :
PANCHASHIL INDUSTRIES (NASHIK) PVT. LTD.

Details of Receiver (Billed to) :
EFACEC INDIA PVT.LTD. (C-4)













PLOT NO C-4 PLOT NO D-50
GARWARE - XLO LINK ROAD MIDC AREA

MIDC AREA AMBAD SATPUR

NASHIK Pin: 422010 NASHIK Pin:

Maharashtra State Code - MH-27 Maharashtra State Code - MH-27









K/A: MR. SUNIL BHABAD Mob: 9823261150 K/A: MR. SUNIL BHABAD Mob: 9823261150
GSTIN- 27AACCE4200H1Z4 GSTIN- 27AAHCP1181B1ZQ

Description of Goods GSTHSNCode[ Uom [Qty | Rate |

BOX FOR PACKING, SIZE BY CUSTOMER (Inclusive of - 44151000 NOS 7 2,044.00
Box, Desiccant Pouch, Stretch Film, Strap & Buckle, Edge
Protector) (for C-04 Panchashil Spares, Box ID = 600 x 500 x
400)

BOX FOR PACKING SIZE BY CUSTOMER. (Inclusive of - 44151000
Box, Desiccant Pouch, Stretch Film, Strap & Buckle, Edge
Protector) (for C-04 Panchashil Spares, Box ID = 800 x 660 x
500)

BOX FOR PACKING SIZE BY CUSTOMER - (Inclusive of - 44151000
Box, Desiccant Pouch, Stretch Film, Strap & Buckle, Edge
Protector) (for C-04 Panchashil Spares, Box ID = 800 x 660 x
1000)

BOX FOR PACKING SIZE BY CUSTOMER: (Inclusive of - 44151000
Box, Desiccant Pouch, Stretch Film, Strap & Buckle, Edge

Protector) (for C-04 Panchashil Spares, Box ID = 600 x 600 x
600)



Total Amount













2,764.00












3,772.00









2,544.00



oe
R F623 666 f





<

















Payment Terms: Within 60 Days from the date of Invoice, Total Taxable Value: 11,124.00



Invoice Total Rs.(In Words) | THIRTEEN THOUSAND ONE HUNDRED TWENTY-SIX ONLY SGST: 9.00 % 1,001.16
IGST: 0.00 %

Important Note- If you have any complaint regarding Quantity or Rate or Tots Sid 13,126.32
Sizes or Quality then it should be reported to us by e-mail witin 3 days from Freight / Loading / Insurance:

receipt of material otherwise we will consider your fully acceptance to
material delivered as well to Invoice submitted. Round Up/Off 70.32
Invoice Total : 13,126.00

Note: 1) All the transactions & bill are subject to Nashik jurisdiction.2) If any discrepancy that to be
For SHAKUNTECH PACKING PVT. LTD.

brought to our notice within 3 days from the date of material receipt.3) Interest @24% P.A. will be

collected from buyer in addition to the bill amount if payment of this bill is not received within due
———<———

date.
Authorised Signatory
































Issue Date & Time: Removal Date & Time:







{Tilo
13-Aug-2019

Vehicle No.:
MHS EG o&ls



13-Aug-2019 16:59

Mode Of Transport- Road


----------------------------------------


"""

pattern = r'\b\d{2}[A-Z]{5}\d{4}[A-Z]\d[Z][A-Z]\b'

gstin_numbers = re.findall(pattern, text)
print(gstin_numbers)
# Out:
# ['27AAOCS8097E1ZP', '27AAHCP1181B1ZQ']

# %%
pattern = r'(?:PO No\.|Purchase Order No\.):[^\w]*(\w+)'

po_numbers = re.findall(pattern, text)
print(po_numbers)
# Out:
# ['CG1902164']

# %%
pattern_invoice_no = r'Invoice No\.[^\w]*(\d{2}-\d{2} \/ \d{4})'
pattern_invoice_date = r'Invoice Date\: ([^\n]+)'

invoice_numbers = re.findall(pattern_invoice_no, text)
invoice_dates = re.findall(pattern_invoice_date, text)

print(invoice_numbers)
print(invoice_dates)
# Out:
# ['19-20 / 0630']
# ['13-Aug-2019']

# %%
pattern_taxable_value = r'Total Taxable Value\:[^\w]*([\d,.]+)'

taxable_values = re.findall(pattern_taxable_value, text)

print(taxable_values)
# Out:
# ['11,124.00']

# %%
pattern_invoice_total = r'Invoice Total[^\w]*:([^\n]*)'

invoice_totals = re.findall(pattern_invoice_total, text)

print(invoice_totals)
# Out:
# [' 13,126.00']

# %%
pattern_vendor_name = r'MR\. .+'

vendor_names = re.findall(pattern_vendor_name, text)


print(vendor_names)
# Out:
# ['MR. SUNIL BHABAD Mob: 9823261150 K/A: MR. SUNIL BHABAD Mob: 9823261150']

# %%
import re
import json

# Example extracted text
text = """
Extracted Text from Image 3:

An ISO 9001:2015 Certified Company

Survey No. 527, Nashik-Mumbai Highway, Village Gonde (Dumala), Tal. Igatpuri, Dist. Nashik, Pin 422403, Maharashtra, India.
Phone : +91 9552 193193 | Email : sunil.ghube@shakuntechpack.com / shakuntechpac@yahoo.com | Web : www.shakuntechpack.com

CIN:U74950MH2010PTC208397 | PAN No.: AAOCS8097E | IEC No.: 3110018179 | GSTIN: 27AAOCS8097E1ZP

Original for Receipient/Buyer

TAX INVOICE
PO No.: CG1902164 PO Dt. 08-Aug-2019] Invoice No. 19-20 / 0630 Invoice Date: 13-Aug-2019














Details of Consignee (Shipped to) :
PANCHASHIL INDUSTRIES (NASHIK) PVT. LTD.

Details of Receiver (Billed to) :
EFACEC INDIA PVT.LTD. (C-4)













PLOT NO C-4 PLOT NO D-50
GARWARE - XLO LINK ROAD MIDC AREA

MIDC AREA AMBAD SATPUR

NASHIK Pin: 422010 NASHIK Pin:

Maharashtra State Code - MH-27 Maharashtra State Code - MH-27









K/A: MR. SUNIL BHABAD Mob: 9823261150 K/A: MR. SUNIL BHABAD Mob: 9823261150
GSTIN- 27AACCE4200H1Z4 GSTIN- 27AAHCP1181B1ZQ

Description of Goods GSTHSNCode[ Uom [Qty | Rate |

BOX FOR PACKING, SIZE BY CUSTOMER (Inclusive of - 44151000 NOS 7 2,044.00
Box, Desiccant Pouch, Stretch Film, Strap & Buckle, Edge
Protector) (for C-04 Panchashil Spares, Box ID = 600 x 500 x
400)

BOX FOR PACKING SIZE BY CUSTOMER. (Inclusive of - 44151000
Box, Desiccant Pouch, Stretch Film, Strap & Buckle, Edge
Protector) (for C-04 Panchashil Spares, Box ID = 800 x 660 x
500)

BOX FOR PACKING SIZE BY CUSTOMER - (Inclusive of - 44151000
Box, Desiccant Pouch, Stretch Film, Strap & Buckle, Edge
Protector) (for C-04 Panchashil Spares, Box ID = 800 x 660 x
1000)

BOX FOR PACKING SIZE BY CUSTOMER: (Inclusive of - 44151000
Box, Desiccant Pouch, Stretch Film, Strap & Buckle, Edge

Protector) (for C-04 Panchashil Spares, Box ID = 600 x 600 x
600)



Total Amount













2,764.00












3,772.00









2,544.00



oe
R F623 666 f





<

















Payment Terms: Within 60 Days from the date of Invoice, Total Taxable Value: 11,124.00



Invoice Total Rs.(In Words) | THIRTEEN THOUSAND ONE HUNDRED TWENTY-SIX ONLY SGST: 9.00 % 1,001.16
IGST: 0.00 %

Important Note- If you have any complaint regarding Quantity or Rate or Tots Sid 13,126.32
Sizes or Quality then it should be reported to us by e-mail witin 3 days from Freight / Loading / Insurance:

receipt of material otherwise we will consider your fully acceptance to
material delivered as well to Invoice submitted. Round Up/Off 70.32
Invoice Total : 13,126.00

Note: 1) All the transactions & bill are subject to Nashik jurisdiction.2) If any discrepancy that to be
For SHAKUNTECH PACKING PVT. LTD.

brought to our notice within 3 days from the date of material receipt.3) Interest @24% P.A. will be

collected from buyer in addition to the bill amount if payment of this bill is not received within due
———<———

date.
Authorised Signatory
































Issue Date & Time: Removal Date & Time:







{Tilo
13-Aug-2019

Vehicle No.:
MHS EG o&ls



13-Aug-2019 16:59

Mode Of Transport- Road

"""

# Define patterns for different information
pattern_gstin = r'\b\d{2}[A-Z]{5}\d{4}[A-Z]\d[Z][A-Z]\b'
pattern_po = r'(?:PO No\.|Purchase Order No\.): (\w+)'
pattern_invoice_no = r'Invoice No\.: (\S+)'
pattern_invoice_date = r'Invoice Date: (\S+)'
pattern_total_taxable_value = r'Total Taxable Value: (\S+)'
pattern_invoice_total = r'Invoice Total : (\S+)'
pattern_address = r'MR\. .+\n.+\n.+'  # Modify this pattern for address extraction

# Extract information using regex
gstin_match = re.search(pattern_gstin, text)
gstin = gstin_match.group(0) if gstin_match else None

po_match = re.search(pattern_po, text)
po_number = po_match.group(1) if po_match else None

invoice_no_match = re.search(pattern_invoice_no, text)
invoice_number = invoice_no_match.group(1) if invoice_no_match else None

invoice_date_match = re.search(pattern_invoice_date, text)
invoice_date = invoice_date_match.group(1) if invoice_date_match else None

total_taxable_value_match = re.search(pattern_total_taxable_value, text)
total_taxable_value = total_taxable_value_match.group(1) if total_taxable_value_match else None

invoice_total_match = re.search(pattern_invoice_total, text)
invoice_total = invoice_total_match.group(1) if invoice_total_match else None

address_texts = re.findall(pattern_address, text)
addresses = []

for address_text in address_texts:
    lines = address_text.split('\n')
    if len(lines) >= 3:
        name = lines[0]
        address = lines[1] + lines[2]
        addresses.append({'name': name, 'address': address})

# Create a dictionary with extracted information
data = {
    'GSTIN': gstin,
    'PO Number': po_number,
    'Invoice Number': invoice_number,
    'Invoice Date': invoice_date,
    'Total Taxable Value': total_taxable_value,
    'Invoice Total': invoice_total,
    'vendor_names': vendor_names
}

# Convert dictionary to JSON and save to a file
output_filename = 'extracted_data.json'
with open(output_filename, 'w') as json_file:
    json.dump(data, json_file, indent=4)

print(f"Extracted data saved to {output_filename}")
# Out:
# Extracted data saved to extracted_data.json
